# %% [markdown]
# # Bokeh example
# ## first attempt

# %%
from bokeh.io import output_notebook, show
from bokeh.plotting import figure
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %%
import pandas as pd

# %%
from bokeh.layouts import column
from bokeh.models import CustomJS, ColumnDataSource, Slider

# %%
def get_file_as_str(filepath):
    filestring = ""
    with open(filepath) as p:
        filestring = p.read()
    return filestring

# %%
x = [x*0.005 for x in range(0, 201)]

source = ColumnDataSource(data=dict(x=x, y=x))

plot = figure(plot_width=400, plot_height=400)
plot.line('x', 'y', source=source, line_width=3, line_alpha=0.6)

slider = Slider(start=0.1, end=6, value=1, step=.1, title="power")

update_curve = CustomJS(args=dict(source=source, slider=slider), code=get_file_as_str("./callback.js"))
slider.js_on_change('value', update_curve)


show(column(slider, plot))
# Out:
#   <div class="bk-root" id="bc1774ef-e435-4e5b-8c95-f3b90fb33aa1" data-root-id="1145"></div>

# %%
cand = pd.read_csv("candidates.csv")
